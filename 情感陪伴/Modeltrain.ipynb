# %%
from transformers import AutoModel
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from transformers import AutoModel
#       2
# ----> 3 model = AutoModel.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct-GGUF")
#
# File d:\anaconda3\envs\transformers\Lib\site-packages\transformers\models\auto\auto_factory.py:336, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     333 if kwargs.get("quantization_config") is not None:
#     334     _ = kwargs.pop("quantization_config")
# --> 336 config, kwargs = AutoConfig.from_pretrained(
#     337     pretrained_model_name_or_path,
#     338     return_unused_kwargs=True,
#     339     code_revision=code_revision,
#     340     _commit_hash=commit_hash,
#     341     **hub_kwargs,
#     342     **kwargs,
#     343 )
# ...
